# %%
import pandas as pd
import seaborn as sns

# %%
january = pd.read_csv('data\JC-201601-citibike-tripdata.csv')
feburary = pd.read_csv('data\JC-201602-citibike-tripdata.csv')
march = pd.read_csv('data\JC-201603-citibike-tripdata.csv')
april = pd.read_csv('data\JC-201604-citibike-tripdata.csv')
may = pd.read_csv('data\JC-201605-citibike-tripdata.csv')
june = pd.read_csv('data\JC-201606-citibike-tripdata.csv')
july = pd.read_csv('data\JC-201607-citibike-tripdata.csv')
august = pd.read_csv('data\JC-201608-citibike-tripdata.csv')
sept = pd.read_csv('data\JC-201609-citibike-tripdata.csv')
oct = pd.read_csv('data\JC-201610-citibike-tripdata.csv')
nov = pd.read_csv('data\JC-201611-citibike-tripdata.csv')
dec = pd.read_csv('data\JC-201612-citibike-tripdata.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\J'
# <>:2: SyntaxWarning: invalid escape sequence '\J'
# <>:3: SyntaxWarning: invalid escape sequence '\J'
# <>:4: SyntaxWarning: invalid escape sequence '\J'
# <>:5: SyntaxWarning: invalid escape sequence '\J'
# <>:6: SyntaxWarning: invalid escape sequence '\J'
# <>:7: SyntaxWarning: invalid escape sequence '\J'
# <>:8: SyntaxWarning: invalid escape sequence '\J'
# <>:9: SyntaxWarning: invalid escape sequence '\J'
# <>:10: SyntaxWarning: invalid escape sequence '\J'
# <>:11: SyntaxWarning: invalid escape sequence '\J'
# <>:12: SyntaxWarning: invalid escape sequence '\J'
# <>:1: SyntaxWarning: invalid escape sequence '\J'
# <>:2: SyntaxWarning: invalid escape sequence '\J'
# <>:3: SyntaxWarning: invalid escape sequence '\J'
# <>:4: SyntaxWarning: invalid escape sequence '\J'
# <>:5: SyntaxWarning: invalid escape sequence '\J'
# <>:6: SyntaxWarning: invalid escape sequence '\J'
# <>:7: SyntaxWarning: invalid escape sequence '\J'
# ...

# %%
january.head(10)
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            362  2016-01-01 00:02:52  2016-01-01 00:08:54              3186
# 1            200  2016-01-01 00:18:22  2016-01-01 00:21:42              3186
# 2            202  2016-01-01 00:18:25  2016-01-01 00:21:47              3186
# 3            248  2016-01-01 00:23:13  2016-01-01 00:27:21              3209
# 4            903  2016-01-01 01:03:20  2016-01-01 01:18:24              3195
# 5            883  2016-01-01 01:03:28  2016-01-01 01:18:11              3195
# 6            445  2016-01-01 01:07:45  2016-01-01 01:15:11              3186
# 7            192  2016-01-01 01:18:51  2016-01-01 01:22:03              3211
# 8            409  2016-01-01 01:23:44  2016-01-01 01:30:34              3187
# 9            285  2016-01-01 01:25:12  2016-01-01 01:29:57              3187
#
#   Start Station Name  Start Station Latitude  Start Station Longitude  \
# ...

# %%
citibike = pd.concat([january,feburary,march,april,may,june,july,august,sept,oct,nov,dec])

# %%
citibike.head(10)
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            362  2016-01-01 00:02:52  2016-01-01 00:08:54              3186
# 1            200  2016-01-01 00:18:22  2016-01-01 00:21:42              3186
# 2            202  2016-01-01 00:18:25  2016-01-01 00:21:47              3186
# 3            248  2016-01-01 00:23:13  2016-01-01 00:27:21              3209
# 4            903  2016-01-01 01:03:20  2016-01-01 01:18:24              3195
# 5            883  2016-01-01 01:03:28  2016-01-01 01:18:11              3195
# 6            445  2016-01-01 01:07:45  2016-01-01 01:15:11              3186
# 7            192  2016-01-01 01:18:51  2016-01-01 01:22:03              3211
# 8            409  2016-01-01 01:23:44  2016-01-01 01:30:34              3187
# 9            285  2016-01-01 01:25:12  2016-01-01 01:29:57              3187
#
#   Start Station Name  Start Station Latitude  Start Station Longitude  \
# ...

# %%
citibike.shape
# Out:
# (247584, 15)

# %%
citibike.isnull().sum()
# Out:
# Trip Duration                  0
# Start Time                     0
# Stop Time                      0
# Start Station ID               0
# Start Station Name             0
# Start Station Latitude         0
# Start Station Longitude        0
# End Station ID                 0
# End Station Name               0
# End Station Latitude           0
# End Station Longitude          0
# Bike ID                        0
# User Type                    380
# Birth Year                 18999
# Gender                         0
# dtype: int64

# %%
citibike.dtypes
# Out:
# Trip Duration                int64
# Start Time                  object
# Stop Time                   object
# Start Station ID             int64
# Start Station Name          object
# Start Station Latitude     float64
# Start Station Longitude    float64
# End Station ID               int64
# End Station Name            object
# End Station Latitude       float64
# End Station Longitude      float64
# Bike ID                      int64
# User Type                   object
# Birth Year                 float64
# Gender                       int64
# dtype: object

# %%
citibike["Birth Year"] = citibike["Birth Year"].fillna(citibike["Birth Year"].median())

# %%
citibike["User Type"].value_counts()
# Out:
# User Type
# Subscriber    231683
# Customer       15521
# Name: count, dtype: int64

# %%
citibike.dropna()
# Out:
#        Trip Duration           Start Time            Stop Time  \
# 0                362  2016-01-01 00:02:52  2016-01-01 00:08:54
# 1                200  2016-01-01 00:18:22  2016-01-01 00:21:42
# 2                202  2016-01-01 00:18:25  2016-01-01 00:21:47
# 3                248  2016-01-01 00:23:13  2016-01-01 00:27:21
# 4                903  2016-01-01 01:03:20  2016-01-01 01:18:24
# ...              ...                  ...                  ...
# 15109            557  2016-12-31 23:10:16  2016-12-31 23:19:33
# 15110           2749  2016-12-31 23:29:39  2017-01-01 00:15:29
# 15111            173  2016-12-31 23:44:37  2016-12-31 23:47:31
# 15112           2424  2016-12-31 23:44:50  2017-01-01 00:25:14
# 15113           2419  2016-12-31 23:44:50  2017-01-01 00:25:10
#
#        Start Station ID Start Station Name  Start Station Latitude  \
# 0                  3186      Grove St PATH               40.719586
# 1                  3186      Grove St PATH               40.719586
# ...

# %%
citibike.dtypes
# Out:
# Trip Duration                int64
# Start Time                  object
# Stop Time                   object
# Start Station ID             int64
# Start Station Name          object
# Start Station Latitude     float64
# Start Station Longitude    float64
# End Station ID               int64
# End Station Name            object
# End Station Latitude       float64
# End Station Longitude      float64
# Bike ID                      int64
# User Type                   object
# Birth Year                 float64
# Gender                       int64
# dtype: object

# %%
duplicates = citibike.duplicated()

# %%
duplicates.value_counts()
# Out:
# False    247584
# Name: count, dtype: int64

# %%
citibike.columns
# Out:
# Index(['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID',
#        'Start Station Name', 'Start Station Latitude',
#        'Start Station Longitude', 'End Station ID', 'End Station Name',
#        'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
#        'Birth Year', 'Gender'],
#       dtype='object')

# %%
citibike['Bike ID'].value_counts()
# Out:
# Bike ID
# 24613    968
# 24497    930
# 24572    903
# 24412    864
# 24561    864
#         ...
# 21413      1
# 19605      1
# 14786      1
# 25308      1
# 18062      1
# Name: count, Length: 566, dtype: int64

# %%
citibike['Bike ID'].nunique()
# Out:
# 566

# %%
# Visualization
sns.set(style="whitegrid")
sns.countplot(x="User Type", data=citibike.reset_index(drop=True))
# Out:
# <Axes: xlabel='User Type', ylabel='count'>

# %%
import matplotlib.pyplot as plt
plt.plot(citibike["Trip Duration"])
plt.title("User Type Distribution")
# Out:
# Text(0.5, 1.0, 'User Type Distribution')

# %%
sns.countplot(x="Gender", data=citibike.reset_index(drop=True))
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
plt.plot(citibike["Trip Duration"])
plt.xlabel("Trip Duration")
plt.ylabel("Count")
plt.title("Trip Duration Distribution")
plt.show()
